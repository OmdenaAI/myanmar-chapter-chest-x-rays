# %% [markdown]
# <h1><center><font size="8">CNN Model for Tuberculosis Detection</font></center></h1>

# %% [markdown]
# # <a id='1'>Importing Packages</a>

# %%
import tensorflow as tf
print(f"TensorFlow has access to the following devices:\n{tf.config.list_physical_devices()}")
print(f"TensorFlow version: {tf.__version__}")
# Out:
# TensorFlow has access to the following devices:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# TensorFlow version: 2.13.0

# %%
# importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

import warnings
warnings.simplefilter("ignore")

import tensorflow as tf
from keras import Model
from keras.models import load_model, Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard, CSVLogger, ReduceLROnPlateau
from keras.applications.vgg16 import VGG16
from keras.metrics import AUC, Precision, Recall

from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
from sklearn.utils import class_weight

import os

from utils import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # <a id='2'>Augmentation through ImageDataGenerator</a>

# %% [markdown]
# ## <a id='21'>Generating the Datasets</a>

# %%
# generating augmentations through ImageDataGenerator
image_generator = ImageDataGenerator(rescale=1./255)


# assigning paths
train_folder = 'data/Tuberculosis/augmented_sorted/train'
val_folder = 'data/Tuberculosis/augmented_sorted/val'
test_folder = 'data/Tuberculosis/augmented_sorted/test'

train_generator = image_generator.flow_from_directory(train_folder, 
                                                      batch_size=16, 
                                                      shuffle=True, 
                                                      class_mode='binary',
                                                      target_size=(224, 224),
                                                      seed=42)

val_generator = image_generator.flow_from_directory(val_folder,
                                                    target_size=(224, 224),
                                                    batch_size = 16,
                                                    shuffle=True,
                                                    class_mode = 'binary',
                                                    seed = 42)

test_generator = image_generator.flow_from_directory(test_folder,
                                                     target_size = (224, 224),
                                                     batch_size = 1,
                                                     class_mode = 'binary',
                                                     shuffle=False, 
                                                     seed=42)

STEP_SIZE_TRAIN = train_generator.n // train_generator.batch_size
STEP_SIZE_VALID = val_generator.n // val_generator.batch_size
STEP_SIZE_TEST = test_generator.n // test_generator.batch_size
# Out:
# Found 9822 images belonging to 2 classes.
# Found 2456 images belonging to 2 classes.
# Found 3289 images belonging to 1 classes.

# %%
# calculate class weights
total_tb = len(os.listdir(os.path.join(train_folder, 'TB')))
total_healthy = len(os.listdir(os.path.join(train_folder, 'Non-TB')))

weight_for_0 = total_tb / (total_healthy + total_tb)
weight_for_1 = total_healthy / (total_healthy + total_tb)

class_weights = {0: weight_for_0, 1: weight_for_1}
class_weights
# Out:
# {0: 0.38098147016900835, 1: 0.6190185298309917}

# %% [markdown]
# ## <a id='22'>Constructing and Compiling the Model</a>

# %%
# create model
def create_model(input_shape):
    return Sequential([
        
        Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape),
        BatchNormalization(),
        Conv2D(filters=32, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),
        
        Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),
        
        Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        Conv2D(filters=128, kernel_size=(3, 3), activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2)),   
        
        Flatten(),
        Dense(units=128, activation='relu'),
        Dropout(0.2),
        Dense(units=1, activation='sigmoid')
        ])

# save model
model = create_model((160, 160, 3))

# compile model
model.compile(loss = 'binary_crossentropy',
              optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.01),
              metrics = ['accuracy', AUC(), AUC(curve='PR'), Precision(), Recall()])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 222, 222, 32)      896
#
#  batch_normalization_12 (Ba  (None, 222, 222, 32)      128
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 220, 220, 32)      9248
#
#  batch_normalization_13 (Ba  (None, 220, 220, 32)      128
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 110, 110, 32)      0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 108, 108, 64)      18496
#
#  batch_normalization_14 (Ba  (None, 108, 108, 64)      256
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 106, 106, 64)      36928
#
#  batch_normalization_15 (Ba  (None, 106, 106, 64)      256
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 53, 53, 64)        0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 51, 51, 128)       73856
#
#  batch_normalization_16 (Ba  (None, 51, 51, 128)       512
#  tchNormalization)
#
#  conv2d_17 (Conv2D)          (None, 49, 49, 128)       147584
#
#  batch_normalization_17 (Ba  (None, 49, 49, 128)       512
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 73728)             0
#
#  dense_4 (Dense)             (None, 128)               9437312
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 9726241 (37.10 MB)
# Trainable params: 9725345 (37.10 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %% [markdown]
# ## <a id='23'>Defining Callbacks</a>

# %%
# define callbacks
# earlyStopping = EarlyStopping(monitor = 'val_loss', 
#                               verbose = 1, 
#                               mode = 'min', 
#                               patience = 4)
lr_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                 patience = 3,
                                 verbose = 1,
                                 factor = 0.5,
                                 min_lr = 0.00001)
filepath = "modeling/log_cnn1/model.{epoch:02d}-{val_loss:.2f}.hdf5"
mcp_save = ModelCheckpoint(filepath, 
                           verbose = 1, 
                           monitor = 'val_loss', 
                           mode = 'min')
csv_logger = CSVLogger('modeling/log_cnn1/log.csv')
log_dir = "modeling/log_cnn1/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_cb = TensorBoard(log_dir = log_dir,
                             histogram_freq = 1,
                             update_freq = 'batch')

# %% [markdown]
# ## <a id='24'>Training the Model</a>

# %%
# train model
history = model.fit_generator(generator = train_generator,
                              steps_per_epoch = STEP_SIZE_TRAIN,
                              validation_data = val_generator,
                              validation_steps = STEP_SIZE_VALID,
                              epochs = 30,
                              class_weight = class_weights,
                              callbacks = [mcp_save, lr_reduction, csv_logger])
# Out:
# Epoch 1/30
# 2023-08-13 23:58:21.072131: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 613/613 [==============================] - ETA: 0s - loss: 4359.4907 - accuracy: 0.6958 - auc_4: 0.6879 - auc_5: 0.5457 - precision_2: 0.5924 - recall_2: 0.6483
# 2023-08-14 00:00:23.288280: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: saving model to modeling/log_cnn1/model.01-428231.53.hdf5
# 613/613 [==============================] - 154s 249ms/step - loss: 4359.4907 - accuracy: 0.6958 - auc_4: 0.6879 - auc_5: 0.5457 - precision_2: 0.5924 - recall_2: 0.6483 - val_loss: 428231.5312 - val_accuracy: 0.3815 - val_auc_4: 0.5000 - val_auc_5: 0.3815 - val_precision_2: 0.3815 - val_recall_2: 1.0000 - lr: 0.0100
# Epoch 2/30
# 613/613 [==============================] - ETA: 0s - loss: 18543.2070 - accuracy: 0.7324 - auc_4: 0.7282 - auc_5: 0.5861 - precision_2: 0.6326 - recall_2: 0.7101
# Epoch 2: saving model to modeling/log_cnn1/model.02-326410.25.hdf5
# 613/613 [==============================] - 152s 247ms/step - loss: 18543.2070 - accuracy: 0.7324 - auc_4: 0.7282 - auc_5: 0.5861 - precision_2: 0.6326 - recall_2: 0.7101 - val_loss: 326410.2500 - val_accuracy: 0.3766 - val_auc_4: 0.4901 - val_auc_5: 0.3768 - val_precision_2: 0.3768 - val_recall_2: 0.9690 - lr: 0.0100
# Epoch 3/30
# 613/613 [==============================] - ETA: 0s - loss: 48399.5039 - accuracy: 0.7566 - auc_4: 0.7524 - auc_5: 0.6150 - precision_2: 0.6628 - recall_2: 0.7350
# Epoch 3: saving model to modeling/log_cnn1/model.03-99306.75.hdf5
# 613/613 [==============================] - 152s 248ms/step - loss: 48399.5039 - accuracy: 0.7566 - auc_4: 0.7524 - auc_5: 0.6150 - precision_2: 0.6628 - recall_2: 0.7350 - val_loss: 99306.7500 - val_accuracy: 0.6691 - val_auc_4: 0.7150 - val_auc_5: 0.5308 - val_precision_2: 0.5391 - val_recall_2: 0.9078 - lr: 0.0100
# Epoch 4/30
# 613/613 [==============================] - ETA: 0s - loss: 35223.6562 - accuracy: 0.8034 - auc_4: 0.8011 - auc_5: 0.6751 - precision_2: 0.7205 - recall_2: 0.7914
# Epoch 4: saving model to modeling/log_cnn1/model.04-39886.32.hdf5
# 613/613 [==============================] - 152s 247ms/step - loss: 35223.6562 - accuracy: 0.8034 - auc_4: 0.8011 - auc_5: 0.6751 - precision_2: 0.7205 - recall_2: 0.7914 - val_loss: 39886.3242 - val_accuracy: 0.7712 - val_auc_4: 0.7915 - val_auc_5: 0.6274 - val_precision_2: 0.6474 - val_recall_2: 0.8766 - lr: 0.0100
# Epoch 5/30
# 613/613 [==============================] - ETA: 0s - loss: 25464.1484 - accuracy: 0.8365 - auc_4: 0.8353 - auc_5: 0.7204 - precision_2: 0.7620 - recall_2: 0.8303
# Epoch 5: saving model to modeling/log_cnn1/model.05-54456.01.hdf5
# 613/613 [==============================] - 152s 247ms/step - loss: 25464.1484 - accuracy: 0.8365 - auc_4: 0.8353 - auc_5: 0.7204 - precision_2: 0.7620 - recall_2: 0.8303 - val_loss: 54456.0117 - val_accuracy: 0.8562 - val_auc_4: 0.8404 - val_auc_5: 0.7678 - val_precision_2: 0.8366 - val_recall_2: 0.7738 - lr: 0.0100
# Epoch 6/30
# 613/613 [==============================] - ETA: 0s - loss: 38670.9883 - accuracy: 0.8151 - auc_4: 0.8146 - auc_5: 0.6899 - precision_2: 0.7321 - recall_2: 0.8122
# Epoch 6: saving model to modeling/log_cnn1/model.06-320595.91.hdf5
# 613/613 [==============================] - 155s 253ms/step - loss: 38670.9883 - accuracy: 0.8151 - auc_4: 0.8146 - auc_5: 0.6899 - precision_2: 0.7321 - recall_2: 0.8122 - val_loss: 320595.9062 - val_accuracy: 0.5400 - val_auc_4: 0.6181 - val_auc_5: 0.4487 - val_precision_2: 0.4507 - val_recall_2: 0.9464 - lr: 0.0100
# Epoch 7/30
# 613/613 [==============================] - ETA: 0s - loss: 88981.2188 - accuracy: 0.7911 - auc_4: 0.7904 - auc_5: 0.6573 - precision_2: 0.7008 - recall_2: 0.7875
# Epoch 7: saving model to modeling/log_cnn1/model.07-913130.12.hdf5
# 613/613 [==============================] - 154s 252ms/step - loss: 88981.2188 - accuracy: 0.7911 - auc_4: 0.7904 - auc_5: 0.6573 - precision_2: 0.7008 - recall_2: 0.7875 - val_loss: 913130.1250 - val_accuracy: 0.6319 - val_auc_4: 0.6908 - val_auc_5: 0.5056 - val_precision_2: 0.5099 - val_recall_2: 0.9401 - lr: 0.0100
# Epoch 8/30
# 613/613 [==============================] - ETA: 0s - loss: 127412.3594 - accuracy: 0.7900 - auc_4: 0.7901 - auc_5: 0.6555 - precision_2: 0.6978 - recall_2: 0.7904
# Epoch 8: saving model to modeling/log_cnn1/model.08-256716.97.hdf5
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 613/613 [==============================] - 150s 245ms/step - loss: 127412.3594 - accuracy: 0.7900 - auc_4: 0.7901 - auc_5: 0.6555 - precision_2: 0.6978 - recall_2: 0.7904 - val_loss: 256716.9688 - val_accuracy: 0.4837 - val_auc_4: 0.5265 - val_auc_5: 0.3958 - val_precision_2: 0.3989 - val_recall_2: 0.7057 - lr: 0.0100
# Epoch 9/30
# 613/613 [==============================] - ETA: 0s - loss: 111656.3984 - accuracy: 0.8157 - auc_4: 0.8186 - auc_5: 0.6885 - precision_2: 0.7255 - recall_2: 0.8309
# Epoch 9: saving model to modeling/log_cnn1/model.09-155912.84.hdf5
# 613/613 [==============================] - 150s 244ms/step - loss: 111656.3984 - accuracy: 0.8157 - auc_4: 0.8186 - auc_5: 0.6885 - precision_2: 0.7255 - recall_2: 0.8309 - val_loss: 155912.8438 - val_accuracy: 0.8456 - val_auc_4: 0.8263 - val_auc_5: 0.7533 - val_precision_2: 0.8301 - val_recall_2: 0.7462 - lr: 0.0050
# Epoch 10/30
# 613/613 [==============================] - ETA: 0s - loss: 105216.4141 - accuracy: 0.8187 - auc_4: 0.8199 - auc_5: 0.6935 - precision_2: 0.7327 - recall_2: 0.8253
# Epoch 10: saving model to modeling/log_cnn1/model.10-214575.39.hdf5
# 613/613 [==============================] - 148s 242ms/step - loss: 105216.4141 - accuracy: 0.8187 - auc_4: 0.8199 - auc_5: 0.6935 - precision_2: 0.7327 - recall_2: 0.8253 - val_loss: 214575.3906 - val_accuracy: 0.8297 - val_auc_4: 0.8045 - val_auc_5: 0.7359 - val_precision_2: 0.8274 - val_recall_2: 0.6988 - lr: 0.0050
# Epoch 11/30
# 613/613 [==============================] - ETA: 0s - loss: 122212.6172 - accuracy: 0.8074 - auc_4: 0.8078 - auc_5: 0.6788 - precision_2: 0.7199 - recall_2: 0.8098
# Epoch 11: saving model to modeling/log_cnn1/model.11-243141.52.hdf5
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 613/613 [==============================] - 150s 244ms/step - loss: 122212.6172 - accuracy: 0.8074 - auc_4: 0.8078 - auc_5: 0.6788 - precision_2: 0.7199 - recall_2: 0.8098 - val_loss: 243141.5156 - val_accuracy: 0.7974 - val_auc_4: 0.8039 - val_auc_5: 0.6620 - val_precision_2: 0.6954 - val_recall_2: 0.8314 - lr: 0.0050
# Epoch 12/30
# 613/613 [==============================] - ETA: 0s - loss: 89329.8438 - accuracy: 0.8254 - auc_4: 0.8262 - auc_5: 0.7030 - precision_2: 0.7424 - recall_2: 0.8295
# Epoch 12: saving model to modeling/log_cnn1/model.12-206727.64.hdf5
# 613/613 [==============================] - 153s 250ms/step - loss: 89329.8438 - accuracy: 0.8254 - auc_4: 0.8262 - auc_5: 0.7030 - precision_2: 0.7424 - recall_2: 0.8295 - val_loss: 206727.6406 - val_accuracy: 0.7880 - val_auc_4: 0.8063 - val_auc_5: 0.6472 - val_precision_2: 0.6677 - val_recall_2: 0.8832 - lr: 0.0025
# Epoch 13/30
# 613/613 [==============================] - ETA: 0s - loss: 85434.5234 - accuracy: 0.8139 - auc_4: 0.8150 - auc_5: 0.6871 - precision_2: 0.7268 - recall_2: 0.8199
# Epoch 13: saving model to modeling/log_cnn1/model.13-112156.74.hdf5
# 613/613 [==============================] - 153s 250ms/step - loss: 85434.5234 - accuracy: 0.8139 - auc_4: 0.8150 - auc_5: 0.6871 - precision_2: 0.7268 - recall_2: 0.8199 - val_loss: 112156.7422 - val_accuracy: 0.8889 - val_auc_4: 0.8746 - val_auc_5: 0.8232 - val_precision_2: 0.8859 - val_recall_2: 0.8139 - lr: 0.0025
# Epoch 14/30
# 613/613 [==============================] - ETA: 0s - loss: 85651.5625 - accuracy: 0.8199 - auc_4: 0.8202 - auc_5: 0.6959 - precision_2: 0.7364 - recall_2: 0.8215
# Epoch 14: saving model to modeling/log_cnn1/model.14-556941.19.hdf5
# 613/613 [==============================] - 151s 247ms/step - loss: 85651.5625 - accuracy: 0.8199 - auc_4: 0.8202 - auc_5: 0.6959 - precision_2: 0.7364 - recall_2: 0.8215 - val_loss: 556941.1875 - val_accuracy: 0.5752 - val_auc_4: 0.6358 - val_auc_5: 0.4644 - val_precision_2: 0.4698 - val_recall_2: 0.8907 - lr: 0.0025
# Epoch 15/30
# 613/613 [==============================] - ETA: 0s - loss: 77406.6719 - accuracy: 0.8296 - auc_4: 0.8300 - auc_5: 0.7098 - precision_2: 0.7493 - recall_2: 0.8316
# Epoch 15: saving model to modeling/log_cnn1/model.15-221397.08.hdf5
# 613/613 [==============================] - 152s 248ms/step - loss: 77406.6719 - accuracy: 0.8296 - auc_4: 0.8300 - auc_5: 0.7098 - precision_2: 0.7493 - recall_2: 0.8316 - val_loss: 221397.0781 - val_accuracy: 0.7643 - val_auc_4: 0.7870 - val_auc_5: 0.6187 - val_precision_2: 0.6371 - val_recall_2: 0.8817 - lr: 0.0025
# Epoch 16/30
# 613/613 [==============================] - ETA: 0s - loss: 97924.8281 - accuracy: 0.8122 - auc_4: 0.8137 - auc_5: 0.6844 - precision_2: 0.7236 - recall_2: 0.8204
# Epoch 16: saving model to modeling/log_cnn1/model.16-113313.24.hdf5
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 613/613 [==============================] - 151s 246ms/step - loss: 97924.8281 - accuracy: 0.8122 - auc_4: 0.8137 - auc_5: 0.6844 - precision_2: 0.7236 - recall_2: 0.8204 - val_loss: 113313.2422 - val_accuracy: 0.8730 - val_auc_4: 0.8691 - val_auc_5: 0.7784 - val_precision_2: 0.8204 - val_recall_2: 0.8530 - lr: 0.0025
# Epoch 17/30
# 613/613 [==============================] - ETA: 0s - loss: 59589.0000 - accuracy: 0.8524 - auc_4: 0.8525 - auc_5: 0.7427 - precision_2: 0.7805 - recall_2: 0.8526
# Epoch 17: saving model to modeling/log_cnn1/model.17-98935.88.hdf5
# 613/613 [==============================] - 150s 245ms/step - loss: 59589.0000 - accuracy: 0.8524 - auc_4: 0.8525 - auc_5: 0.7427 - precision_2: 0.7805 - recall_2: 0.8526 - val_loss: 98935.8750 - val_accuracy: 0.8868 - val_auc_4: 0.8745 - val_auc_5: 0.8147 - val_precision_2: 0.8726 - val_recall_2: 0.8230 - lr: 0.0012
# Epoch 18/30
# 613/613 [==============================] - ETA: 0s - loss: 56624.1602 - accuracy: 0.8520 - auc_4: 0.8530 - auc_5: 0.7413 - precision_2: 0.7777 - recall_2: 0.8569
# Epoch 18: saving model to modeling/log_cnn1/model.18-90012.34.hdf5
# 613/613 [==============================] - 151s 246ms/step - loss: 56624.1602 - accuracy: 0.8520 - auc_4: 0.8530 - auc_5: 0.7413 - precision_2: 0.7777 - recall_2: 0.8569 - val_loss: 90012.3438 - val_accuracy: 0.8783 - val_auc_4: 0.8621 - val_auc_5: 0.8076 - val_precision_2: 0.8760 - val_recall_2: 0.7936 - lr: 0.0012
# Epoch 19/30
# 613/613 [==============================] - ETA: 0s - loss: 54572.5586 - accuracy: 0.8543 - auc_4: 0.8550 - auc_5: 0.7448 - precision_2: 0.7812 - recall_2: 0.8579
# Epoch 19: saving model to modeling/log_cnn1/model.19-152962.55.hdf5
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 613/613 [==============================] - 150s 244ms/step - loss: 54572.5586 - accuracy: 0.8543 - auc_4: 0.8550 - auc_5: 0.7448 - precision_2: 0.7812 - recall_2: 0.8579 - val_loss: 152962.5469 - val_accuracy: 0.7655 - val_auc_4: 0.7631 - val_auc_5: 0.6262 - val_precision_2: 0.6721 - val_recall_2: 0.7527 - lr: 0.0012
# Epoch 20/30
# 613/613 [==============================] - ETA: 0s - loss: 42354.6719 - accuracy: 0.8649 - auc_4: 0.8656 - auc_5: 0.7605 - precision_2: 0.7955 - recall_2: 0.8686
# Epoch 20: saving model to modeling/log_cnn1/model.20-87575.30.hdf5
# 613/613 [==============================] - 173s 283ms/step - loss: 42354.6719 - accuracy: 0.8649 - auc_4: 0.8656 - auc_5: 0.7605 - precision_2: 0.7955 - recall_2: 0.8686 - val_loss: 87575.3047 - val_accuracy: 0.8685 - val_auc_4: 0.8516 - val_auc_5: 0.7910 - val_precision_2: 0.8617 - val_recall_2: 0.7805 - lr: 6.2500e-04
# Epoch 21/30
# 613/613 [==============================] - ETA: 0s - loss: 41048.6172 - accuracy: 0.8703 - auc_4: 0.8704 - auc_5: 0.7693 - precision_2: 0.8046 - recall_2: 0.8709
# Epoch 21: saving model to modeling/log_cnn1/model.21-70054.51.hdf5
# 613/613 [==============================] - 152s 248ms/step - loss: 41048.6172 - accuracy: 0.8703 - auc_4: 0.8704 - auc_5: 0.7693 - precision_2: 0.8046 - recall_2: 0.8709 - val_loss: 70054.5078 - val_accuracy: 0.9011 - val_auc_4: 0.8895 - val_auc_5: 0.8395 - val_precision_2: 0.8940 - val_recall_2: 0.8403 - lr: 6.2500e-04
# Epoch 22/30
# 613/613 [==============================] - ETA: 0s - loss: 37814.0742 - accuracy: 0.8706 - auc_4: 0.8711 - auc_5: 0.7697 - precision_2: 0.8042 - recall_2: 0.8732
# Epoch 22: saving model to modeling/log_cnn1/model.22-67434.65.hdf5
# 613/613 [==============================] - 150s 245ms/step - loss: 37814.0742 - accuracy: 0.8706 - auc_4: 0.8711 - auc_5: 0.7697 - precision_2: 0.8042 - recall_2: 0.8732 - val_loss: 67434.6484 - val_accuracy: 0.8991 - val_auc_4: 0.8858 - val_auc_5: 0.8382 - val_precision_2: 0.8968 - val_recall_2: 0.8303 - lr: 6.2500e-04
# Epoch 23/30
# 613/613 [==============================] - ETA: 0s - loss: 39950.7617 - accuracy: 0.8692 - auc_4: 0.8700 - auc_5: 0.7671 - precision_2: 0.8012 - recall_2: 0.8735
# Epoch 23: saving model to modeling/log_cnn1/model.23-66529.29.hdf5
# 613/613 [==============================] - 153s 250ms/step - loss: 39950.7617 - accuracy: 0.8692 - auc_4: 0.8700 - auc_5: 0.7671 - precision_2: 0.8012 - recall_2: 0.8735 - val_loss: 66529.2891 - val_accuracy: 0.9052 - val_auc_4: 0.8939 - val_auc_5: 0.8458 - val_precision_2: 0.8986 - val_recall_2: 0.8466 - lr: 6.2500e-04
# Epoch 24/30
# 613/613 [==============================] - ETA: 0s - loss: 39730.8828 - accuracy: 0.8674 - auc_4: 0.8672 - auc_5: 0.7655 - precision_2: 0.8018 - recall_2: 0.8662
# Epoch 24: saving model to modeling/log_cnn1/model.24-74830.95.hdf5
# 613/613 [==============================] - 152s 247ms/step - loss: 39730.8828 - accuracy: 0.8674 - auc_4: 0.8672 - auc_5: 0.7655 - precision_2: 0.8018 - recall_2: 0.8662 - val_loss: 74830.9531 - val_accuracy: 0.8840 - val_auc_4: 0.8767 - val_auc_5: 0.8021 - val_precision_2: 0.8495 - val_recall_2: 0.8458 - lr: 6.2500e-04
# Epoch 25/30
# 613/613 [==============================] - ETA: 0s - loss: 35524.5859 - accuracy: 0.8736 - auc_4: 0.8735 - auc_5: 0.7753 - precision_2: 0.8105 - recall_2: 0.8727
# Epoch 25: saving model to modeling/log_cnn1/model.25-76085.34.hdf5
# 613/613 [==============================] - 147s 240ms/step - loss: 35524.5859 - accuracy: 0.8736 - auc_4: 0.8735 - auc_5: 0.7753 - precision_2: 0.8105 - recall_2: 0.8727 - val_loss: 76085.3438 - val_accuracy: 0.8689 - val_auc_4: 0.8553 - val_auc_5: 0.7868 - val_precision_2: 0.8497 - val_recall_2: 0.7979 - lr: 6.2500e-04
# Epoch 26/30
# 613/613 [==============================] - ETA: 0s - loss: 37583.9492 - accuracy: 0.8711 - auc_4: 0.8711 - auc_5: 0.7708 - precision_2: 0.8060 - recall_2: 0.8712
# Epoch 26: saving model to modeling/log_cnn1/model.26-349579.38.hdf5
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 613/613 [==============================] - 149s 243ms/step - loss: 37583.9492 - accuracy: 0.8711 - auc_4: 0.8711 - auc_5: 0.7708 - precision_2: 0.8060 - recall_2: 0.8712 - val_loss: 349579.3750 - val_accuracy: 0.8787 - val_auc_4: 0.8626 - val_auc_5: 0.8081 - val_precision_2: 0.8762 - val_recall_2: 0.7947 - lr: 6.2500e-04
# Epoch 27/30
# 613/613 [==============================] - ETA: 0s - loss: 31937.6211 - accuracy: 0.8829 - auc_4: 0.8827 - auc_5: 0.7895 - precision_2: 0.8232 - recall_2: 0.8819
# Epoch 27: saving model to modeling/log_cnn1/model.27-106816.84.hdf5
# 613/613 [==============================] - 152s 247ms/step - loss: 31937.6211 - accuracy: 0.8829 - auc_4: 0.8827 - auc_5: 0.7895 - precision_2: 0.8232 - recall_2: 0.8819 - val_loss: 106816.8438 - val_accuracy: 0.9007 - val_auc_4: 0.8888 - val_auc_5: 0.8396 - val_precision_2: 0.8949 - val_recall_2: 0.8383 - lr: 3.1250e-04
# Epoch 28/30
# 613/613 [==============================] - ETA: 0s - loss: 30551.5898 - accuracy: 0.8844 - auc_4: 0.8855 - auc_5: 0.7905 - precision_2: 0.8216 - recall_2: 0.8897
# Epoch 28: saving model to modeling/log_cnn1/model.28-92347.22.hdf5
# 613/613 [==============================] - 152s 248ms/step - loss: 30551.5898 - accuracy: 0.8844 - auc_4: 0.8855 - auc_5: 0.7905 - precision_2: 0.8216 - recall_2: 0.8897 - val_loss: 92347.2188 - val_accuracy: 0.9028 - val_auc_4: 0.8917 - val_auc_5: 0.8408 - val_precision_2: 0.8934 - val_recall_2: 0.8455 - lr: 3.1250e-04
# Epoch 29/30
# 613/613 [==============================] - ETA: 0s - loss: 29313.5020 - accuracy: 0.8904 - auc_4: 0.8899 - auc_5: 0.8023 - precision_2: 0.8353 - recall_2: 0.8877
# Epoch 29: saving model to modeling/log_cnn1/model.29-82818.23.hdf5
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 613/613 [==============================] - 151s 245ms/step - loss: 29313.5020 - accuracy: 0.8904 - auc_4: 0.8899 - auc_5: 0.8023 - precision_2: 0.8353 - recall_2: 0.8877 - val_loss: 82818.2344 - val_accuracy: 0.8783 - val_auc_4: 0.8598 - val_auc_5: 0.8119 - val_precision_2: 0.8861 - val_recall_2: 0.7818 - lr: 3.1250e-04
# Epoch 30/30
# 613/613 [==============================] - ETA: 0s - loss: 28810.1328 - accuracy: 0.8870 - auc_4: 0.8875 - auc_5: 0.7952 - precision_2: 0.8270 - recall_2: 0.8895
# Epoch 30: saving model to modeling/log_cnn1/model.30-62071.63.hdf5
# 613/613 [==============================] - 150s 245ms/step - loss: 28810.1328 - accuracy: 0.8870 - auc_4: 0.8875 - auc_5: 0.7952 - precision_2: 0.8270 - recall_2: 0.8895 - val_loss: 62071.6328 - val_accuracy: 0.8938 - val_auc_4: 0.8874 - val_auc_5: 0.8179 - val_precision_2: 0.8619 - val_recall_2: 0.8600 - lr: 1.5625e-04

# %%
history = pd.read_csv("modeling/log_cnn1/log.csv")
history
# Out:
#     epoch  accuracy     auc_4     auc_5           loss        lr  precision_2  \
# 0       0  0.695799  0.687889  0.545671    4359.490723  0.010000     0.592375
# 1       1  0.732409  0.728182  0.586132   18543.207031  0.010000     0.632570
# 2       2  0.756578  0.752431  0.615001   48399.503906  0.010000     0.662805
# 3       3  0.803386  0.801084  0.675088   35223.656250  0.010000     0.720477
# 4       4  0.836529  0.835331  0.720413   25464.148438  0.010000     0.761975
# 5       5  0.815113  0.814554  0.689921   38670.988281  0.010000     0.732095
# 6       6  0.791148  0.790447  0.657341   88981.218750  0.010000     0.700763
# 7       7  0.790026  0.790099  0.655450  127412.359375  0.010000     0.697823
# 8       8  0.815725  0.818637  0.688480  111656.398438  0.005000     0.725467
# 9       9  0.818682  0.819946  0.693535  105216.414062  0.005000     0.732716
# 10     10  0.807363  0.807829  0.678770  122212.617188  0.005000     0.719857
# 11     11  0.825413  0.826190  0.702994   89329.843750  0.002500     0.742392
# 12     12  0.813889  0.815046  0.687075   85434.523438  0.002500     0.726755
# 13     13  0.819906  0.820215  0.695855   85651.562500  0.002500     0.736388
# 14     14  0.829594  0.830046  0.709802   77406.671875  0.002500     0.749277
# 15     15  0.812156  0.813740  0.684386   97924.828125  0.002500     0.723560
# 16     16  0.852437  0.852460  0.742667   59589.000000  0.001250     0.780500
# 17     17  0.852029  0.852966  0.741315   56624.160156  0.001250     0.777670
# 18     18  0.854273  0.854978  0.744784   54572.558594  0.001250     0.781242
# 19     19  0.864879  0.865589  0.760532   42354.671875  0.000625     0.795538
# 20     20  0.870283  0.870405  0.769327   41048.617188  0.000625     0.804552
# 21     21  0.870589  0.871096  0.769702   37814.074219  0.000625     0.804187
# 22     22  0.869162  0.869987  0.767068   39950.761719  0.000625     0.801227
# 23     23  0.867428  0.867186  0.765507   39730.882812  0.000625     0.801784
# 24     24  0.873649  0.873472  0.775327   35524.585938  0.000625     0.810529
# 25     25  0.871099  0.871122  0.770776   37583.949219  0.000625     0.806044
# 26     26  0.882929  0.882724  0.789456   31937.621094  0.000313     0.823206
# 27     27  0.884356  0.885461  0.790455   30551.589844  0.000313     0.821552
# 28     28  0.890373  0.889867  0.802328   29313.501953  0.000313     0.835262
# 29     29  0.887008  0.887478  0.795232   28810.132812  0.000156     0.827028
#
#     recall_2  val_accuracy  val_auc_4  val_auc_5       val_loss  \
# 0   0.648302      0.381536   0.500000   0.381536  428231.531250
# 1   0.710118      0.376634   0.490090   0.376844  326410.250000
# 2   0.735011      0.669118   0.714968   0.530794   99306.750000
# 3   0.791388      0.771242   0.791537   0.627352   39886.324219
# 4   0.830300      0.856209   0.840389   0.767836   54456.011719
# 5   0.812199      0.540033   0.618089   0.448737  320595.906250
# 6   0.787513      0.631944   0.690807   0.505584  913130.125000
# 7   0.790405      0.483660   0.526545   0.395811  256716.968750
# 8   0.830880      0.845588   0.826346   0.753313  155912.843750
# 9   0.825261      0.829657   0.804526   0.735852  214575.390625
# 10  0.809791      0.797386   0.803948   0.662009  243141.515625
# 11  0.829451      0.787990   0.806273   0.647240  206727.640625
# 12  0.819909      0.888889   0.874566   0.823226  112156.742188
# 13  0.821515      0.575163   0.635767   0.464389  556941.187500
# 14  0.831596      0.764297   0.787039   0.618711  221397.078125
# 15  0.820396      0.872958   0.869114   0.778409  113313.242188
# 16  0.852556      0.886846   0.874541   0.814679   98935.875000
# 17  0.856914      0.878268   0.862092   0.807649   90012.343750
# 18  0.857945      0.765523   0.763062   0.626210  152962.546875
# 19  0.868576      0.868464   0.851618   0.791019   87575.304688
# 20  0.870916      0.901144   0.889457   0.839470   70054.507812
# 21  0.873228      0.899101   0.885811   0.838215   67434.648438
# 22  0.873462      0.905229   0.893930   0.845779   66529.289062
# 23  0.866167      0.883987   0.876677   0.802105   74830.953125
# 24  0.872727      0.868873   0.855308   0.786775   76085.343750
# 25  0.871218      0.878676   0.862627   0.808148  349579.375000
# 26  0.881864      0.900735   0.888782   0.839617  106816.843750
# 27  0.889722      0.902778   0.891744   0.840789   92347.218750
# 28  0.887731      0.878268   0.859845   0.811882   82818.234375
# 29  0.889454      0.893791   0.887363   0.817872   62071.632812
#
#     val_precision_2  val_recall_2
# 0          0.381536      1.000000
# 1          0.376769      0.968951
# 2          0.539147      0.907824
# 3          0.647385      0.876609
# 4          0.836616      0.773848
# 5          0.450740      0.946409
# 6          0.509861      0.940107
# 7          0.398907      0.705693
# 8          0.830144      0.746237
# 9          0.827411      0.698821
# 10         0.695418      0.831364
# 11         0.667747      0.883173
# 12         0.885914      0.813904
# 13         0.469757      0.890675
# 14         0.637141      0.881720
# 15         0.820433      0.853004
# 16         0.872582      0.822961
# 17         0.876033      0.793583
# 18         0.672084      0.752677
# 19         0.861702      0.780514
# 20         0.893957      0.840300
# 21         0.896752      0.830290
# 22         0.898633      0.846566
# 23         0.849462      0.845824
# 24         0.849658      0.797861
# 25         0.876179      0.794652
# 26         0.894857      0.838330
# 27         0.893424      0.845494
# 28         0.886061      0.781818
# 29         0.861884      0.860043

# %%
# evaluate model by displaying metrics with visualization
plt.style.use('seaborn')
sixplot2(history, 'auc_4', 'val_auc_4', 'auc_5', 'val_auc_5', 'precision_2', 'val_precision_2', 'recall_2', 'val_recall_2')

# %% [markdown]
# ## Loading Best Model

# %%
model_2 = load_model('../logs/log_cnn1a/model.16-0.15.hdf5')

# %% [markdown]
# ## <a id='47'>Predicting on Holdout Set</a>

# %%
# get testing accuracy and loss
test_generator.reset()
score = model.evaluate_generator(test_generator, verbose = 1)

print("Loss: " + str(score[0]))
print("Accuracy: " + str(score[1]))
# print("Precision: " + str(score[2]))
# print("Recall: " + str(score[3]))
# print("ROC-AUC: " + str(score[4]))
# print("PR-AUC: " + str(score[5]))
# Out:
# 3289/3289 [==============================] - 67s 20ms/step - loss: 367616.0312 - accuracy: 0.7498 - auc_4: 0.0000e+00 - auc_5: 0.0000e+00 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00
# Loss: 367616.03125
# Accuracy: 0.7497719526290894
# Precision: 0.0
# Recall: 0.0
# ROC-AUC: 0.0
# PR-AUC: 0.0

# %%
image_list = glob.glob('data/Tuberculosis/augmented_sorted/test/test/*.png')

# %%
def is_image_corrupted(image_path):
    try:
        # Try to open the image
        with Image.open(image_path) as img:
            img.verify()  # This method checks for corruption in the image
        return False  # Image is not corrupted
    except Exception as e:
        print(f"Image is corrupted: {e}")
        return True  # Image is corrupted

# %%
for image in image_list:
    if is_image_corrupted(image):
        print(image)
        os.remove(image)
# Out:
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_2576.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2576.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_2210.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2210.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1719.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1719.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_3126.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_3126.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_2238.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2238.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1731.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1731.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1057.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1057.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1043.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1043.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1725.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1725.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_3132.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_3132.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_1916.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1916.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_516.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_516.png
# Image is corrupted: cannot identify image file 'data/Tuberculosis/augmented_sorted/test/test/unknown_728.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_728.png

# %%
for image in image_list:
    if is_image_corrupted(image):
        print(image)
# Out:
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_2576.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2576.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_2210.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2210.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1719.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1719.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_3126.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_3126.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_2238.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_2238.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1731.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1731.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1057.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1057.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1043.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1043.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1725.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1725.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_3132.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_3132.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_1916.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_1916.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_516.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_516.png
# Image is corrupted: [Errno 2] No such file or directory: 'data/Tuberculosis/augmented_sorted/test/test/unknown_728.png'
# data/Tuberculosis/augmented_sorted/test/test/unknown_728.png

# %%
# visualization for confusion matrix
test_generator.reset()
pred = model.predict_generator(test_generator, steps = STEP_SIZE_TEST, verbose = 1)
y_true = test_generator.classes
y_pred = pred > 0.5
make_confusion_matrix(y_true, y_pred)
# Out:
# 3289/3289 [==============================] - 27s 8ms/step

# %% [markdown]
# ## <a id='56'>Evaluating the Model</a>

# %%
# create visualizations for training metrics
plt.style.use('seaborn')
history_3 = pd.read_csv("../logs/log_cnn/log.csv")
sixplot2(history_3, "auc", "val_auc", "auc_1", "val_auc_1", "precision", "val_precision", "recall", "val_recall")

# %%
# display dataframe of training metrics
history_3

# %%
# plot accuracy and loss visualizations
plt.style.use('seaborn')
train_val_metrics2(20, history_3)

# %% [markdown]
# ## Loading Best Model

# %%
model_3 = load_model('../logs/log_cnn/model.09-0.17.hdf5')

# %% [markdown]
# ## <a id='58'>Predicting on Holdout Set</a>

# %%
# display confusion matrix visualization
test_generator.reset()
pred_3 = model_3.predict_generator(test_generator, steps = STEP_SIZE_TEST, verbose = 1)
y_true = test_generator.classes
y_pred_3 = pred_3 > 0.5
cf = confusion_matrix(y_true, y_pred_3)
draw_confusion_matrix(cf, ['TN','FP','FN','TP'], (5, 5), "Confusion Matrix for Simplified CNN Model")

# %%
# get testing accuracy and loss
test_generator.reset()
score_3 = model_3.evaluate_generator(test_generator, verbose = 1)

print("Loss: " + str(score_3[0]))
print("Accuracy: " + str(score_3[1]))
print("Precision: " + str(score_3[2]))
print("Recall: " + str(score_3[3]))
print("ROC-AUC: " + str(score_3[4]))
print("PR-AUC: " + str(score_3[5]))

# %% [markdown]
# # Analysis

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier

# %%
# create model
def create_model(input_shape):
    model = Sequential()
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))

    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))
    
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))   
    model.add(Dropout(0.3))
    
    model.add(Flatten())
    model.add(Dense(units=128, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1, activation='sigmoid')

    return model

seed = 42
tf.random.set_seed(seed)    
    
model.compile(loss = 'binary_crossentropy',
              optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=0.01),
              metrics = ['accuracy', AUC(), AUC(curve='PR'), Precision(), Recall()])    
              
filepath = "model.h5"
#Save weights into file
model.save_weights(filepath)
# save model
model = create_model((224, 224, 3))

# compile model
